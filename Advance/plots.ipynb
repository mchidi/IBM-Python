# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o-b')

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data", loc='right')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.grid(c = 'green', ls = '--', lw = 0.5)

plt.plot(x, y)

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap=plt.cm.plasma, s=45)

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

myexplode = [0.1, 0.05, 0.05, 0.05]

plt.pie(y, labels=mylabels, explode=myexplode, shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x24b9b1438f0>,
#   <matplotlib.patches.Wedge at 0x24b9b1437a0>,
#   <matplotlib.patches.Wedge at 0x24b9b1a8e60>,
#   <matplotlib.patches.Wedge at 0x24b9b1a92e0>],
#  [Text(0.5447886197087486, 1.0692078188246832, 'Apples'),
#   Text(-1.1358415849470398, 0.17989967733433163, 'Bananas'),
#   Text(-0.17989967733433168, -1.1358415849470398, 'Cherries'),
#   Text(1.0246574930403216, -0.5220890938875504, 'Dates')])

# %%
x = np.array([9, 12, 5, 14])
y = np.array([35, 25, 25, 15])
plt.bar(x, y)
# Out:
# <BarContainer object of 4 artists>
