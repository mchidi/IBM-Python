# %%
import requests
import json

import os 
from PIL import Image
from IPython.display import IFrame

# %%
# url = 'https://www.ibm.com/'
res = requests.get(url='https://www.ibm.com/')

res.status_code
info = {
  "statusCode": res.status_code,
  "headers": res.headers,
  "text": res.text,
  "JSON": res.json,
  "CONTENT": res.content
}

info
# Out:
# {'statusCode': 200,
#  'headers': {'Content-Type': 'text/html;charset=utf-8', 'X-Dispatcher': 'prod-publish-1', 'X-Vhost': 'publish', 'X-Content-Type-Options': 'nosniff', 'Last-Modified': 'Mon, 18 Dec 2023 19:40:49 GMT', 'X-Frame-Options': 'SAMEORIGIN', 'CF-Cache-Status': 'DYNAMIC', 'Server': 'cloudflare', 'CF-RAY': '8379ef0c7ccd76d5-LHR', 'Cache-Control': 'max-age=171', 'Expires': 'Tue, 19 Dec 2023 00:24:56 GMT', 'X-Akamai-Transformed': '9 12965 0 pmb=mTOE,2', 'Content-Encoding': 'gzip', 'Date': 'Tue, 19 Dec 2023 00:22:05 GMT', 'Content-Length': '13221', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'Strict-Transport-Security': 'max-age=31536000', 'x-ibm-trace': 'www-dipatcher: dynamic rule'},
#  'text': '\n<!DOCTYPE HTML>\n<html lang="en-uk">\n<head>\n    \n    \n    \n    \n    <meta charset="UTF-8"/>\n    <meta name="languageCode" content="en"/>\n    <meta name="countryCode" content="uk"/>\n    <meta name="searchTitle" content="IBM - United Kingdom"/>\n    <meta name="focusArea" content="No Contact Module"/>\n    <title>IBM - United Kingdom</title>\n    <link rel="icon" href="/content/dam/adobe-cms/default-images/favicon.svg"/>\n    \n    <meta name="description" content="For more than a century, IBM has been a global technology innovator, leading advances in AI, automation and hybrid cloud solutions that help businesses grow."/>\n    <meta name="template" content="full-width-layout"/>\n    <meta name="viewport" content="width=device-width, initial-scale=1"/>\n    <meta name="robots" content="index, follow"/>\n    \n    <link rel="canonical" href="https://www.ibm.com/uk-en"/>\n    <style id="anti-flicker-style">\n        :not(:defined) {\n          visibility: hidden;\n        }\n    </style>\n    <script type="text/javascript" id="anti-flicker-script">\n        (async () => {\n          await customElements.whenDefined(\'dds-masthead-container\');\n          document.getElementById(\'anti-flicker-style\').remove();\n          document.getElementById(\'anti-flicker-script\').remove();\n        })()\n    </script>\n    \n\n    <script type="text/javascript">\n        window.searchKey = {\n            templateName: \'full\\u002Dwidth\\u002Dlayout\',\n            taxonomylist: \'\',\n            L0Tag: \'CMaaS Focus Areas,Topics,Brands,Industries,Geography,Compliance Entities,Products\',\n        }\n    </script>\n\n<!--    <script>\n      (function(s,t,a,n){s[t]||(s[t]=a,n=s[a]=function(){n.q.push(arguments)},\n      n.q=[],n.v=2,n.l=1*new Date)})(window,"InstanaEumObject","ineum");\n      ineum(\'reportingUrl\', \'https://eum-orange-saas.instana.io\');\n      ineum(\'key\', \'QSUr0uqUS0m37yyre8ntkQ\');\n      ineum(\'trackSessions\');\n    </script>\n    <script defer crossorigin="anonymous" src="https://eum.instana.io/eum.min.js"></script>-->\n\n    \n        <link rel="alternate" hreflang="de-de" href="https://www.ibm.com/de-de"/>\n    \n        <link rel="alternate" hreflang="en-us" href="https://www.ibm.com/"/>\n    \n        <link rel="alternate" hreflang="en-ca" href="https://www.ibm.com/ca-en"/>\n    \n        <link rel="alternate" hreflang="ko-kr" href="https://www.ibm.com/kr-ko"/>\n    \n        <link rel="alternate" hreflang="pt-br" href="https://www.ibm.com/br-pt"/>\n    \n        <link rel="alternate" hreflang="en-in" href="https://www.ibm.com/in-en"/>\n    \n        <link rel="alternate" hreflang="es-es" href="https://www.ibm.com/es-es"/>\n    \n        <link rel="alternate" hreflang="zh-cn" href="https://www.ibm.com/cn-zh"/>\n    \n        <link rel="alternate" hreflang="es-mx" href="https://www.ibm.com/mx-es"/>\n    \n        <link rel="alternate" hreflang="fr-ca" href="https://www.ibm.com/ca-fr"/>\n    \n        <link rel="alternate" hreflang="it-it" href="https://www.ibm.com/it-it"/>\n    \n        <link rel="alternate" hreflang="id-id" href="https://www.ibm.com/id-id"/>\n    \n        <link rel="alternate" hreflang="en-au" href="https://www.ibm.com/au-en"/>\n    \n        <link rel="alternate" hreflang="en-uk" href="https://www.ibm.com/uk-en"/>\n    \n        <link rel="alternate" hreflang="fr-fr" href="https://www.ibm.com/fr-fr"/>\n    \n        <link rel="alternate" hreflang="ja-jp" href="https://www.ibm.com/jp-ja"/>\n    \n    <script type="text/javascript">\n        window.antiFlicker = {\n            active: true,\n            timeout: 3000\n        }\n    </script>\n    <script type="text/javascript">\n        var languageCode = document.getElementsByName(\'languageCode\')[0].content;\n        var countryCode = document.getElementsByName(\'countryCode\')[0].content;\n        var focusArea = document.getElementsByName(\'focusArea\')[0].content;\n        /* Define digital data object based on _ ...
#  'JSON': <bound method Response.json of <Response [200]>>,
#  'CONTENT': b'\n<!DOCTYPE HTML>\n<html lang="en-uk">\n<head>\n    \n    \n    \n    \n    <meta charset="UTF-8"/>\n    <meta name="languageCode" content="en"/>\n    <meta name="countryCode" content="uk"/>\n    <meta name="searchTitle" content="IBM - United Kingdom"/>\n    <meta name="focusArea" content="No Contact Module"/>\n    <title>IBM - United Kingdom</title>\n    <link rel="icon" href="/content/dam/adobe-cms/default-images/favicon.svg"/>\n    \n    <meta name="description" content="For more than a century, IBM has been a global technology innovator, leading advances in AI, automation and hybrid cloud solutions that help businesses grow."/>\n    <meta name="template" content="full-width-layout"/>\n    <meta name="viewport" content="width=device-width, initial-scale=1"/>\n    <meta name="robots" content="index, follow"/>\n    \n    <link rel="canonical" href="https://www.ibm.com/uk-en"/>\n    <style id="anti-flicker-style">\n        :not(:defined) {\n          visibility: hidden;\n        }\n    </style>\n    <script type="text/javascript" id="anti-flicker-script">\n        (async () => {\n          await customElements.whenDefined(\'dds-masthead-container\');\n          document.getElementById(\'anti-flicker-style\').remove();\n          document.getElementById(\'anti-flicker-script\').remove();\n        })()\n    </script>\n    \n\n    <script type="text/javascript">\n        window.searchKey = {\n            templateName: \'full\\u002Dwidth\\u002Dlayout\',\n            taxonomylist: \'\',\n            L0Tag: \'CMaaS Focus Areas,Topics,Brands,Industries,Geography,Compliance Entities,Products\',\n        }\n    </script>\n\n<!--    <script>\n      (function(s,t,a,n){s[t]||(s[t]=a,n=s[a]=function(){n.q.push(arguments)},\n      n.q=[],n.v=2,n.l=1*new Date)})(window,"InstanaEumObject","ineum");\n      ineum(\'reportingUrl\', \'https://eum-orange-saas.instana.io\');\n      ineum(\'key\', \'QSUr0uqUS0m37yyre8ntkQ\');\n      ineum(\'trackSessions\');\n    </script>\n    <script defer crossorigin="anonymous" src="https://eum.instana.io/eum.min.js"></script>-->\n\n    \n        <link rel="alternate" hreflang="de-de" href="https://www.ibm.com/de-de"/>\n    \n        <link rel="alternate" hreflang="en-us" href="https://www.ibm.com/"/>\n    \n        <link rel="alternate" hreflang="en-ca" href="https://www.ibm.com/ca-en"/>\n    \n        <link rel="alternate" hreflang="ko-kr" href="https://www.ibm.com/kr-ko"/>\n    \n        <link rel="alternate" hreflang="pt-br" href="https://www.ibm.com/br-pt"/>\n    \n        <link rel="alternate" hreflang="en-in" href="https://www.ibm.com/in-en"/>\n    \n        <link rel="alternate" hreflang="es-es" href="https://www.ibm.com/es-es"/>\n    \n        <link rel="alternate" hreflang="zh-cn" href="https://www.ibm.com/cn-zh"/>\n    \n        <link rel="alternate" hreflang="es-mx" href="https://www.ibm.com/mx-es"/>\n    \n        <link rel="alternate" hreflang="fr-ca" href="https://www.ibm.com/ca-fr"/>\n    \n        <link rel="alternate" hreflang="it-it" href="https://www.ibm.com/it-it"/>\n    \n        <link rel="alternate" hreflang="id-id" href="https://www.ibm.com/id-id"/>\n    \n        <link rel="alternate" hreflang="en-au" href="https://www.ibm.com/au-en"/>\n    \n        <link rel="alternate" hreflang="en-uk" href="https://www.ibm.com/uk-en"/>\n    \n        <link rel="alternate" hreflang="fr-fr" href="https://www.ibm.com/fr-fr"/>\n    \n        <link rel="alternate" hreflang="ja-jp" href="https://www.ibm.com/jp-ja"/>\n    \n    <script type="text/javascript">\n        window.antiFlicker = {\n            active: true,\n            timeout: 3000\n        }\n    </script>\n    <script type="text/javascript">\n        var languageCode = document.getElementsByName(\'languageCode\')[0].content;\n        var countryCode = document.getElementsByName(\'countryCode\')[0].content;\n        var focusArea = document.getElementsByName(\'focusArea\')[0].content;\n        /* Define digital data object based  ...

# %%
# Random USER

res = requests.get(url='https://randomuser.me/api/?results=10')

results = json.loads(res.text)

results['results']
# Out:
# [{'gender': 'female',
#   'name': {'title': 'Miss', 'first': 'Jennifer', 'last': 'Schmidl'},
#   'location': {'street': {'number': 2124, 'name': 'Lindenstraße'},
#    'city': 'Olbernhau',
#    'state': 'Brandenburg',
#    'country': 'Germany',
#    'postcode': 16347,
#    'coordinates': {'latitude': '-48.9367', 'longitude': '74.9335'},
#    'timezone': {'offset': '0:00',
#     'description': 'Western Europe Time, London, Lisbon, Casablanca'}},
#   'email': 'jennifer.schmidl@example.com',
#   'login': {'uuid': '8c2739a3-115e-4483-87f5-bce2831725b9',
#    'username': 'greenpanda811',
#    'password': 'windmill',
#    'salt': 'gu5rHnUB',
#    'md5': 'bca816fbbfb425b56433946465c54de3',
#    'sha1': 'bb48dc98a2cfdb401024fb39a843c66ea62c2a9c',
#    'sha256': 'c1b935a110d8ad8885d5dc3d8b063fe9e58068e0ade719bd2ee8f4e101f4f317'},
#   'dob': {'date': '1995-09-04T19:19:14.377Z', 'age': 28},
#   'registered': {'date': '2005-10-13T04:56:16.884Z', 'age': 18},
#   'phone': '0214-1375528',
#   'cell': '0178-4816511',
#   'id': {'name': 'SVNR', 'value': '18 040995 S 714'},
#   'picture': {'large': 'https://randomuser.me/api/portraits/women/52.jpg',
#    'medium': 'https://randomuser.me/api/portraits/med/women/52.jpg',
#    'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/52.jpg'},
#   'nat': 'DE'},
#  {'gender': 'male',
#   'name': {'title': 'Mr', 'first': 'كيان', 'last': 'یاسمی'},
#   'location': {'street': {'number': 5372, 'name': 'میدان انقلاب'},
#    'city': 'یزد',
#    'state': 'آذربایجان شرقی',
#    'country': 'Iran',
#    'postcode': 46089,
#    'coordinates': {'latitude': '2.2673', 'longitude': '-84.1794'},
#    'timezone': {'offset': '0:00',
#     'description': 'Western Europe Time, London, Lisbon, Casablanca'}},
#   'email': 'kyn.ysmy@example.com',
#   'login': {'uuid': 'ed6d1a81-2367-492a-b68b-f0692812217a',
#    'username': 'redsnake183',
#    'password': 'nancy1',
#    'salt': 'MlFfkkhC',
#    'md5': '4c076a2e925ff87b0ab8d37a26c452ea',
#    'sha1': '2fcd1875a1178f58e3a1c55df0d36b0e099ab309',
#    'sha256': '887f07971de1043db9269865d3e33e0525f9334639addcb710a84bb8f8b8abd9'},
#   'dob': {'date': '1963-10-14T12:01:10.363Z', 'age': 60},
#   'registered': {'date': '2015-12-18T16:21:30.720Z', 'age': 8},
#   'phone': '086-02087684',
#   'cell': '0942-791-6253',
#   'id': {'name': '', 'value': None},
#   'picture': {'large': 'https://randomuser.me/api/portraits/men/51.jpg',
#    'medium': 'https://randomuser.me/api/portraits/med/men/51.jpg',
#    'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/51.jpg'},
#   'nat': 'IR'},
#  {'gender': 'male',
#   'name': {'title': 'Mr', 'first': 'Rich', 'last': 'Kelley'},
#   'location': {'street': {'number': 7063, 'name': 'The Crescent'},
#    'city': 'Listowel',
#    'state': 'Monaghan',
#    'country': 'Ireland',
#    'postcode': 83679,
#    'coordinates': {'latitude': '27.6868', 'longitude': '123.4618'},
#    'timezone': {'offset': '+5:30',
#     'description': 'Bombay, Calcutta, Madras, New Delhi'}},
#   'email': 'rich.kelley@example.com',
#   'login': {'uuid': '15a8d904-1eca-4d77-bbf3-a48482c7bbd9',
#    'username': 'brownduck121',
#    'password': 'remember',
#    'salt': 'i2FmP0Zf',
#    'md5': 'f4e4cb2c5efbec3e53897bf0a7ef346e',
#    'sha1': '9885e6005ed122b3644e3ca5ce9782fb904aa2e6',
#    'sha256': 'fabd078f587218241934976aede012d10e7578d2bdbfbbfcae184bcc3ce74b58'},
#   'dob': {'date': '1985-07-07T13:03:03.105Z', 'age': 38},
#   'registered': {'date': '2005-01-20T10:01:26.061Z', 'age': 18},
#   'phone': '051-286-8072',
#   'cell': '081-473-5869',
#   'id': {'name': 'PPS', 'value': '3051654T'},
#   'picture': {'large': 'https://randomuser.me/api/portraits/men/8.jpg',
#    'medium': 'https://randomuser.me/api/portraits/med/men/8.jpg',
#    'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/8.jpg'},
#   'nat': 'IE'},
#  {'gender': 'male',
#   'name': {'title': 'Mr', 'first': 'Aaron', 'last': 'Adam'},
#   'location': {'street': {'number': 5584, 'name': 'Avenue Debrousse'},
#    'city': 'Besançon',
#    'state': 'Loiret',
#    'country': 'France',
#    'postcode': 63352,
#    'coordinates': {'latitude': '33.7659', 'longitude': '114.7185'},
#    'timezone': {'offset': '0:00',
#     'description': 'Western Europe Time, London, Lisbon, Casablanca'}},
#   'email': 'aaron.adam@example.com',
#   'login': {'uuid': '2d83afd1-b330-4b21-93da-e0c36c68c9e6',
#    'username': 'smallpeacock715',
#    'password': 'eleanor',
#    'salt': 'aUwJ4nTs',
#    'md5': '211766168742b6d993b15b2a656acf52',
#    'sha1': 'a3c1ded026af94d397ced575097b8d0a970a81b1',
#    'sha256': 'e697ab387a1fe2c9607d1eed0dcc043dc2d82e7678dd57c49a152b114e7e5303'},
#   'dob': {'date': '1961-12-19T00:56:26.174Z', 'age': 62},
#   'registered': {'date': '2011-04-07T01:08:35.304Z', 'age': 12},
#   'phone': '04-41-76-66-36',
#   'cell': '06-55-15-93-27',
#   'id': {'name': 'INSEE', 'value': '1611151724406 18'},
#   'picture': {'large': 'https://randomuser.me/api/portraits/men/74.jpg',
#    'medium': 'https://randomuser.me/api/portraits/med/men/74.jpg',
#    'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/74.jpg'},
#   'nat': 'FR'},
#  {'gender': 'female',
#   'name': {'title': 'Miss', 'first': 'Antonina', 'last': 'Hals'},
#   'location': {'street': {'number': 4572, 'name': 'Idrettsveien'},
#    'city': 'Bekkjarvik',
#    'state': 'Møre og Romsdal',
#    'country': 'Norway',
#    'postcode': '5693',
#    'coordinates': {'latitude': '-79.0239', 'longitude': '4.6084'},
#    'timezone': {'offset': '0:00',
#     'description': 'Western Europe Time, London, Lisbon, Casablanca'}},
#   'email': 'antonina.hals@example.com',
#   'login': {'uuid': '2a876300-7802-4990-859e-3b45dca47bb7',
#    'username': 'bluewolf134',
#    'password': 'lola',
#    'salt': 'TEZdJC0E',
#    'md5': '051b1908036a544747f99e4b29964ed7',
#    'sha1': '5d7cf4871b7fc3e77373cb0efa8412679e0876ea',
#    'sha256': '808a06a1b0a923935f89c3d36807ea6037a7bb73e44e79885b99d5b521ddc95d'},
#   'dob': {'date': '1965-12-31T05:37:52.047Z', 'age': 57},
#   'registered': {'date': '2015-01-24T22:19:22.769Z', 'age': 8},
#   'phone': '64741717',
#   'cell': '95043807',
#   'id': {'name': 'FN', 'value': '31126511658'},
#   'picture': {'large': 'https://randomuser.me/api/portraits/women/84.jpg',
#    'medium': 'https://randomuser.me/api/portraits/med/women/84.jpg',
#    'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/84.jpg'},
#   'nat': 'NO'},
#  {'gender': 'female',
#   'name': {'title': 'Miss', 'first': 'Sinaida', 'last': 'Jessen'},
#   'location': {'street': {'number': 764, 'name': 'Blumenstraße'},
#    'city': 'Ulrichstein',
#    'state': 'Baden-Württemberg',
#    'country': 'Germany',
#    'postcode': 36998,
#    'coordinates': {'latitude': '-54.2246', 'longitude': '95.4742'},
#    'timezone': {'offset': '0:00',
#     'description': 'Western Europe Time, London, Lisbon, Casablanca'}},
#   'email': 'sinaida.jessen@example.com',
#   'login': {'uuid': 'aba5b992-9e64-4c81-b476-09b914277606',
#    'username': 'organicduck504',
#    'password': 'hockey',
#    'salt': 'dVf9YAyI',
#    'md5': 'd3155e4460abd8dc335a8ba3643d33c9',
#    'sha1': '771872dcc5d7ba71a4eb44e16762efcc651d6d5b',
#    'sha256': '07f20f3d91df725b812577aed88f172e1d182cca5e2f830d8024f673e921ed7f'},
#   'dob': {'date': '1989-07-14T00:45:51.329Z', 'age': 34},
#   'registered': {'date': '2007-11-05T03:05:19.329Z', 'age': 16},
#   'phone': '0761-2193512',
#   'cell': '0172-4312962',
#   'id': {'name': 'SVNR', 'value': '19 130789 J 746'},
#   'picture': {'large': 'https://randomuser.me/api/portraits/women/8.jpg',
#    'medium': 'https://randomuser.me/api/portraits/med/women/8.jpg',
#    'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/8.jpg'},
#   'nat': 'DE'},
#  {'gender': 'male',
#   'name': {'title': 'Mr', 'first': 'Alexander', 'last': 'Turner'},
#   'location': {'street': {'number': 6029, 'name': 'Russell Street'},
#    'city': 'Hamilton',
#    'state': 'Otago',
#    'country': 'New Zealand',
#    'postcode': 18133,
#    'coordinates': {'latitude': '-74.9127', 'longitude': '84.6813'},
#    'timezone': {'offset': '-3:30', 'description': 'Newfoundland'}},
#   'email': 'alexander.turner@example.com',
#   'login': {'uuid': '7d097f78-2e06-4ad8-bb71-c2be8075e1b9',
#    'username': 'blueladybug255',
#    'password': 'filter',
#    'salt': 'ZYxeG8O2',
#    'md5': 'bd72512828f515929c3f99e03b453687',
#    'sha1': '8a77a6dcb93398de47d0e25a7b5ac2b225a42ad3',
#    'sha256': 'ae717dcf07808cc1b0c790efa98d7675078d8909573a6266ed0b5b3e8c03f069'},
#   'dob': {'date': '1947-11-14T09:54:26.091Z', 'age': 76},
#   'registered': {'date': '2008-11-08T15:21:28.887Z', 'age': 15},
#   'phone': '(600)-811-1799',
#   'cell': '(515)-521-3720',
#   'id': {'name': '', 'value': None},
#   'picture': {'large': 'https://randomuser.me/api/portraits/men/42.jpg',
#    'medium': 'https://randomuser.me/api/portraits/med/men/42.jpg',
#    'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/42.jpg'},
#   'nat': 'NZ'},
#  {'gender': 'male',
#   'name': {'title': 'Monsieur', 'first': 'Maël', 'last': 'Mathieu'},
#   'location': {'street': {'number': 4515, 'name': 'Rue Barrème'},
#    'city': 'Oberems',
#    'state': 'Nidwalden',
#    'country': 'Switzerland',
#    'postcode': 9056,
#    'coordinates': {'latitude': '-14.1555', 'longitude': '95.5161'},
#    'timezone': {'offset': '+8:00',
#     'description': 'Beijing, Perth, Singapore, Hong Kong'}},
#   'email': 'mael.mathieu@example.com',
#   'login': {'uuid': '93be6371-2e04-40c1-bd66-87937c41ca34',
#    'username': 'yellowfrog150',
#    'password': 'robin1',
#    'salt': 'eMngLBty',
#    'md5': '061104fc54fc6ac4a5d0af7d6e2b0b73',
#    'sha1': 'ac59b28206f5ca9bc3625c147c56f3c72364d724',
#    'sha256': 'ee91e0943d6d4f4a2bdc92f2c7a307d2b37b1cd283cb1e738c04771aba173b36'},
#   'dob': {'date': '1993-11-12T06:50:44.844Z', 'age': 30},
#   'registered': {'date': '2007-11-11T04:58:03.962Z', 'age': 16},
#   'phone': '077 371 06 12',
#   'cell': '078 877 98 07',
#   'id': {'name': 'AVS', 'value': '756.9913.2823.40'},
#   'picture': {'large': 'https://randomuser.me/api/portraits/men/31.jpg',
#    'medium': 'https://randomuser.me/api/portraits/med/men/31.jpg',
#    'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/31.jpg'},
#   'nat': 'CH'},
#  {'gender': 'female',
#   'name': {'title': 'Ms', 'first': 'Emina', 'last': 'Høgås'},
#   'location': {'street': {'number': 2193, 'name': 'Diakonveien'},
#    'city': 'Lervik',
#    'state': 'Sogn og Fjordane',
#    'country': 'Norway',
#    'postcode': '1255',
#    'coordinates': {'latitude': '-65.8485', 'longitude': '172.0727'},
#    'timezone': {'offset': '+3:30', 'description': 'Tehran'}},
#   'email': 'emina.hogas@example.com',
#   'login': {'uuid': '58134662-4e94-437a-810c-59c491dc618f',
#    'username': 'organicgorilla619',
#    'password': 'wapapapa',
#    'salt': '1QZeRLNz',
#    'md5': '7c6c3f679430b80ef7cf8a6c2b952ac1',
#    'sha1': 'fd273ead00a79b9fc2fb6a048c2c06465a3a22ea',
#    'sha256': 'cea64a74caaee1d5e16281bbf8729f84dab0bec1e3dae702e0a4d89594a3d68e'},
#   'dob': {'date': '1985-02-11T07:52:22.829Z', 'age': 38},
#   'registered': {'date': '2002-09-09T07:16:51.981Z', 'age': 21},
#   'phone': '38617886',
#   'cell': '43548222',
#   'id': {'name': 'FN', 'value': '11028506467'},
#   'picture': {'large': 'https://randomuser.me/api/portraits/women/59.jpg',
#    'medium': 'https://randomuser.me/api/portraits/med/women/59.jpg',
#    'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/59.jpg'},
#   'nat': 'NO'},
#  {'gender': 'female',
#   'name': {'title': 'Miss', 'first': 'Marielle', 'last': 'Schenk'},
#   'location': {'street': {'number': 9317, 'name': 'Kilschans'},
#    'city': 'Spijk gem Lingewaal',
#    'state': 'Limburg',
#    'country': 'Netherlands',
#    'postcode': '0821 MT',
#    'coordinates': {'latitude': '26.7610', 'longitude': '133.4519'},
#    'timezone': {'offset': '-10:00', 'description': 'Hawaii'}},
#   'email': 'marielle.schenk@example.com',
#   'login': {'uuid': '5272056a-10d1-412c-af93-89426b40279a',
#    'username': 'blackpanda375',
#    'password': 'kangaroo',
#    'salt': '9jI8I9w7',
#    'md5': 'd8c763e42d6349a88132b457f6f10e09',
#    'sha1': '475cdbc735ab287c325613571f5f69fc07916f43',
#    'sha256': '0c0d052e4a0c9c8edaf7ed4fff167c93877bfc846d8ee843defa722a35768a3e'},
#   'dob': {'date': '1995-06-07T07:31:22.053Z', 'age': 28},
#   'registered': {'date': '2005-07-23T14:02:17.903Z', 'age': 18},
#   'phone': '(040) 6806281',
#   'cell': '(06) 65823385',
#   'id': {'name': 'BSN', 'value': '37162042'},
#   'picture': {'large': 'https://randomuser.me/api/portraits/women/27.jpg',
#    'medium': 'https://randomuser.me/api/portraits/med/women/27.jpg',
#    'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/27.jpg'},
#   'nat': 'NL'}]

# %%
from randomuser import RandomUser
import pandas as pd

r = RandomUser()

some_list = r.generate_users(10)

name = r.get_full_name()

name

for name in some_list:
  print(name.get_full_name())
# Out:
# Océane Perez
# Natalício Nascimento
# Lisan Bastings
# Florence Edwards
# آوین حسینی
# Carlos Lawson
# Crystal Adams
# Diede Boks
# Ryder Patel
# Lotta Kumpula
